# %% [markdown]
# # Option: Using BART to Transport Product

# %% [markdown]
# ## Included Modules and Packages

# %%
import neo4j

import csv

import math
import numpy as np
import pandas as pd

import psycopg2
from geographiclib.geodesic import Geodesic

# %% [markdown]
# ## Supporting Code

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","w205"))

# %%
session = driver.session(database="neo4j")

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
def my_calculate_box(point, miles):
    "Given a point and miles, calculate the box in form left, right, top, bottom"
    
    geod = Geodesic.WGS84

    kilometers = miles * 1.60934
    meters = kilometers * 1000

    g = geod.Direct(point[0], point[1], 270, meters)
    left = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 90, meters)
    right = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 0, meters)
    top = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 180, meters)
    bottom = (g['lat2'], g['lon2'])
    
    return(left, right, top, bottom)

# %%
def my_station_get_zips(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
#     print("\n-------------------------------------------------------------------------------")
#     print("  Zip Codes within " + str(miles) + " mile(s) of " + station + " BART Station")
#     print("-------------------------------------------------------------------------------\n")
    
    total_population = 0
    
    for row in rows:
        zip = row[0]
        population = row[1]
#         print("     zip:", zip, "  population: ", f'{population:10,}')
        total_population += population
    return float(total_population)    
    
#     print("\n-------------------------------------------------------------------------------")
#     print("  Total Population: ", f'{total_population:10,}')
#     print("-------------------------------------------------------------------------------")

# %%
def cleanse_stations(df):
    """Returns a data frame with unique station names cleansed of line(s) and depart, arrive"""
    
    words = ["blue", "green", "orange", "red", "yellow", "orange", "gray", "depart", "arrive"]
    regex_pattern = r'\b(?:{})\b'.format('|'.join(words))
    df["name"] = df["name"].str.replace(regex_pattern, '')
    return df

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_shortest_path(from_station, to_station):
    "given a from station and to station, run and print the shortest path"
    
    query = "CALL gds.graph.drop('ds_graph', false)"
    session.run(query)

    query = "CALL gds.graph.create('ds_graph', 'Station', 'LINK', {relationshipProperties: 'weight'})"
    session.run(query)

    query = """

    MATCH (source:Station {name: $source}), (target:Station {name: $target})
    CALL gds.shortestPath.dijkstra.stream(
        'ds_graph', 
        { sourceNode: source, 
          targetNode: target, 
          relationshipWeightProperty: 'weight'
        }
    )
    YIELD index, sourceNode, targetNode, totalCost, nodeIds, costs, path
    RETURN
        gds.util.asNode(sourceNode).name AS from,
        gds.util.asNode(targetNode).name AS to,
        totalCost,
        [nodeId IN nodeIds | gds.util.asNode(nodeId).name] AS nodes,
        costs
    ORDER BY index

    """

    result = session.run(query, source=from_station, target=to_station)
    
    for r in result:
        
        total_cost = int(r['totalCost'])
        
        #print("\n--------------------------------")
        #print("   Total Cost: ", total_cost)
        #print("   Minutes: ", round(total_cost / 60.0,1))
        #print("--------------------------------")
        
        nodes = r['nodes']
        costs = r['costs']
        
        i = 0
        previous = 0
        
        for n in nodes:
            
            #print(n + ", " + str(int(costs[i]) - previous)  + ", " + str(int(costs[i])))
            
            previous = int(costs[i])
            i += 1
    
    return total_cost

# %%
def my_station_get_zip_list(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
#     print("\n-------------------------------------------------------------------------------")
#     print("  Zip Codes within " + str(miles) + " mile(s) of " + station + " BART Station")
#     print("-------------------------------------------------------------------------------\n")
    
    total_population = 0
    
    zip_list = []
    
    for row in rows:
        zip = row[0]
        population = row[1]
#         print("     zip:", zip, "  population: ", f'{population:10,}')
        total_population += population
        zip_list.append(row[0])
    return zip_list  
    
#     print("\n-------------------------------------------------------------------------------")
#     print("  Total Population: ", f'{total_population:10,}')
#     print("-------------------------------------------------------------------------------")

# %% [markdown]
# ## Where are our current customers?

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select count(customer_id), zip
from customers
group by zip

"""

customer_locs = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
customer_locs = customer_locs.set_index('zip')
customer_locs
# Out:
#        count
# zip
# 37062      8
# 94066      9
# 75023      7
# 33131    115
# 76180      1
# ...      ...
# 33168     61
# 76012      1
# 33128     76
# 94591      5
# 94158     56
#
# [550 rows x 1 columns]

# %% [markdown]
# # Create population/current customer table based on 5 mile radius from stations.

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select station
from stations
order by station

"""

df = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
df
# Out:
#                  station
# 0            12th Street
# 1    16th Street Mission
# 2            19th Street
# 3    24th Street Mission
# 4                Antioch
# 5                  Ashby
# 6            Balboa Park
# 7               Bay Fair
# 8              Berryessa
# 9          Castro Valley
# 10          Civic Center
# 11              Coliseum
# 12                 Colma
# 13               Concord
# 14             Daly City
# 15     Downtown Berkeley
# 16                Dublin
# 17  El Cerrito del Norte
# 18      El Cerrito Plaza
# 19           Embarcadero
# 20               Fremont
# 21             Fruitvale
# 22             Glen Park
# 23               Hayward
# 24             Lafayette
# 25          Lake Merritt
# 26             MacArthur
# 27              Millbrae
# 28              Milpitas
# 29     Montgomery Street
# 30        North Berkeley
# 31         North Concord
# 32                   OAK
# 33                Orinda
# 34             Pittsburg
# 35      Pittsburg Center
# 36         Pleasant Hill
# 37         Powell Street
# 38              Richmond
# 39             Rockridge
# 40             San Bruno
# 41           San Leandro
# 42                   SFO
# 43         South Hayward
# 44   South San Francisco
# 45            Union City
# 46          Walnut Creek
# 47          Warm Springs
# 48           West Dublin
# 49          West Oakland

# %%
pop_5 = []

for station in df["station"]:
    pop_5.append(my_station_get_zips(station, 5))
    
df["pop_5"] = pop_5
df
# Out:
#                  station     pop_5
# 0            12th Street  510498.0
# 1    16th Street Mission  870044.0
# 2            19th Street  576172.0
# 3    24th Street Mission  989138.0
# 4                Antioch  152632.0
# 5                  Ashby  487206.0
# 6            Balboa Park  936912.0
# 7               Bay Fair  457901.0
# 8              Berryessa  559010.0
# 9          Castro Valley  403433.0
# 10          Civic Center  870044.0
# 11              Coliseum  495903.0
# 12                 Colma  597747.0
# 13               Concord  188050.0
# 14             Daly City  805122.0
# 15     Downtown Berkeley  448042.0
# 16                Dublin  213807.0
# 17  El Cerrito del Norte  369372.0
# 18      El Cerrito Plaza  355903.0
# 19           Embarcadero  698612.0
# 20               Fremont  315645.0
# 21             Fruitvale  544423.0
# 22             Glen Park  986074.0
# 23               Hayward  467447.0
# 24             Lafayette  202640.0
# 25          Lake Merritt  542120.0
# 26             MacArthur  524629.0
# 27              Millbrae  281774.0
# 28              Milpitas  435506.0
# 29     Montgomery Street  826249.0
# 30        North Berkeley  445973.0
# 31         North Concord  165316.0
# 32                   OAK  410051.0
# 33                Orinda  262181.0
# 34             Pittsburg  187733.0
# 35      Pittsburg Center  206117.0
# 36         Pleasant Hill  290825.0
# 37         Powell Street  870044.0
# 38              Richmond  301909.0
# 39             Rockridge  536232.0
# 40             San Bruno  334455.0
# 41           San Leandro  494839.0
# 42                   SFO  320354.0
# 43         South Hayward  411490.0
# 44   South San Francisco  507636.0
# 45            Union City  326572.0
# 46          Walnut Creek  215621.0
# 47          Warm Springs  321651.0
# 48           West Dublin  229219.0
# 49          West Oakland  473317.0

# %%
zips_5 = []

for station in df["station"]:
    zips_5.append(my_station_get_zip_list(station, 5))
    
df["zips_5"] = zips_5
df
# Out:
#                  station     pop_5  \
# 0            12th Street  510498.0
# 1    16th Street Mission  870044.0
# 2            19th Street  576172.0
# 3    24th Street Mission  989138.0
# 4                Antioch  152632.0
# 5                  Ashby  487206.0
# 6            Balboa Park  936912.0
# 7               Bay Fair  457901.0
# 8              Berryessa  559010.0
# 9          Castro Valley  403433.0
# 10          Civic Center  870044.0
# 11              Coliseum  495903.0
# 12                 Colma  597747.0
# 13               Concord  188050.0
# 14             Daly City  805122.0
# 15     Downtown Berkeley  448042.0
# 16                Dublin  213807.0
# 17  El Cerrito del Norte  369372.0
# 18      El Cerrito Plaza  355903.0
# 19           Embarcadero  698612.0
# 20               Fremont  315645.0
# 21             Fruitvale  544423.0
# 22             Glen Park  986074.0
# 23               Hayward  467447.0
# 24             Lafayette  202640.0
# 25          Lake Merritt  542120.0
# 26             MacArthur  524629.0
# 27              Millbrae  281774.0
# 28              Milpitas  435506.0
# 29     Montgomery Street  826249.0
# 30        North Berkeley  445973.0
# 31         North Concord  165316.0
# 32                   OAK  410051.0
# 33                Orinda  262181.0
# 34             Pittsburg  187733.0
# 35      Pittsburg Center  206117.0
# 36         Pleasant Hill  290825.0
# 37         Powell Street  870044.0
# 38              Richmond  301909.0
# 39             Rockridge  536232.0
# 40             San Bruno  334455.0
# 41           San Leandro  494839.0
# 42                   SFO  320354.0
# 43         South Hayward  411490.0
# 44   South San Francisco  507636.0
# 45            Union City  326572.0
# 46          Walnut Creek  215621.0
# 47          Warm Springs  321651.0
# 48           West Dublin  229219.0
# 49          West Oakland  473317.0
#
#                                                zips_5
# 0   [94501, 94502, 94601, 94602, 94606, 94607, 946...
# 1   [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 2   [94501, 94502, 94563, 94601, 94602, 94603, 946...
# 3   [94005, 94014, 94015, 94102, 94103, 94104, 941...
# 4                               [94509, 94531, 94561]
# 5   [94530, 94563, 94602, 94606, 94607, 94608, 946...
# 6   [94005, 94014, 94015, 94080, 94102, 94103, 941...
# 7   [94541, 94542, 94544, 94546, 94577, 94578, 945...
# 8   [95050, 95053, 95054, 95110, 95112, 95113, 951...
# 9   [94541, 94542, 94544, 94546, 94552, 94577, 945...
# 10  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 11  [94501, 94502, 94577, 94578, 94579, 94601, 946...
# 12  [94005, 94014, 94015, 94066, 94080, 94110, 941...
# 13         [94518, 94519, 94520, 94521, 94523, 94597]
# 14  [94005, 94014, 94015, 94080, 94103, 94107, 941...
# 15  [94530, 94563, 94602, 94607, 94608, 94609, 946...
# 16                [94566, 94568, 94582, 94583, 94588]
# 17  [94530, 94564, 94702, 94703, 94704, 94705, 947...
# 18  [94530, 94608, 94609, 94618, 94702, 94703, 947...
# 19  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 20                [94536, 94538, 94539, 94560, 94587]
# 21  [94501, 94502, 94516, 94577, 94601, 94602, 946...
# 22  [94005, 94014, 94015, 94102, 94103, 94104, 941...
# 23  [94541, 94542, 94544, 94545, 94546, 94552, 945...
# 24  [94516, 94523, 94549, 94556, 94563, 94575, 945...
# 25  [94501, 94502, 94601, 94602, 94603, 94606, 946...
# 26  [94501, 94563, 94601, 94602, 94606, 94607, 946...
# 27  [94010, 94030, 94066, 94080, 94128, 94401, 944...
# 28  [95035, 95050, 95053, 95054, 95110, 95112, 951...
# 29  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 30  [94130, 94530, 94602, 94607, 94608, 94609, 946...
# 31                [94518, 94519, 94520, 94521, 94523]
# 32  [94501, 94502, 94577, 94578, 94579, 94580, 946...
# 33  [94516, 94549, 94556, 94563, 94575, 94609, 946...
# 34                       [94518, 94519, 94521, 94565]
# 35                              [94509, 94521, 94565]
# 36  [94518, 94519, 94520, 94523, 94549, 94553, 945...
# 37  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 38  [94530, 94564, 94702, 94706, 94707, 94708, 947...
# 39  [94501, 94516, 94563, 94601, 94602, 94606, 946...
# 40  [94005, 94010, 94014, 94015, 94030, 94044, 940...
# 41  [94502, 94541, 94546, 94577, 94578, 94579, 945...
# 42  [94005, 94010, 94015, 94030, 94044, 94066, 940...
# 43  [94536, 94541, 94542, 94544, 94545, 94578, 945...
# 44  [94005, 94014, 94015, 94030, 94044, 94066, 940...
# 45         [94536, 94542, 94544, 94555, 94560, 94587]
# 46  [94507, 94518, 94523, 94549, 94556, 94575, 945...
# 47  [94536, 94538, 94539, 94560, 94586, 95002, 95035]
# 48         [94552, 94566, 94568, 94582, 94583, 94588]
# 49  [94130, 94501, 94502, 94601, 94602, 94606, 946...

# %%
def get_customers(list):
    
    customers = 0
    
    for zipcode in list:
        
        try:
            
            customers += int(customer_locs.loc[[str(zipcode)],"count"])
        
        except:
            
            continue
        
    return customers

# %%
df["current_customers_5"] = df['zips_5'].apply(get_customers)
df = df.sort_values(by=["current_customers_5"],axis=0,ascending=False)
df
# Out:
#                  station     pop_5  \
# 5                  Ashby  487206.0
# 39             Rockridge  536232.0
# 26             MacArthur  524629.0
# 15     Downtown Berkeley  448042.0
# 30        North Berkeley  445973.0
# 2            19th Street  576172.0
# 25          Lake Merritt  542120.0
# 0            12th Street  510498.0
# 49          West Oakland  473317.0
# 18      El Cerrito Plaza  355903.0
# 21             Fruitvale  544423.0
# 17  El Cerrito del Norte  369372.0
# 33                Orinda  262181.0
# 38              Richmond  301909.0
# 11              Coliseum  495903.0
# 3    24th Street Mission  989138.0
# 22             Glen Park  986074.0
# 10          Civic Center  870044.0
# 37         Powell Street  870044.0
# 1    16th Street Mission  870044.0
# 29     Montgomery Street  826249.0
# 19           Embarcadero  698612.0
# 6            Balboa Park  936912.0
# 41           San Leandro  494839.0
# 32                   OAK  410051.0
# 24             Lafayette  202640.0
# 14             Daly City  805122.0
# 46          Walnut Creek  215621.0
# 36         Pleasant Hill  290825.0
# 12                 Colma  597747.0
# 7               Bay Fair  457901.0
# 44   South San Francisco  507636.0
# 9          Castro Valley  403433.0
# 23               Hayward  467447.0
# 13               Concord  188050.0
# 43         South Hayward  411490.0
# 31         North Concord  165316.0
# 40             San Bruno  334455.0
# 42                   SFO  320354.0
# 27              Millbrae  281774.0
# 34             Pittsburg  187733.0
# 45            Union City  326572.0
# 48           West Dublin  229219.0
# 16                Dublin  213807.0
# 20               Fremont  315645.0
# 47          Warm Springs  321651.0
# 35      Pittsburg Center  206117.0
# 4                Antioch  152632.0
# 28              Milpitas  435506.0
# 8              Berryessa  559010.0
#
#                                                zips_5  current_customers_5
# 5   [94530, 94563, 94602, 94606, 94607, 94608, 946...                 3638
# 39  [94501, 94516, 94563, 94601, 94602, 94606, 946...                 3555
# 26  [94501, 94563, 94601, 94602, 94606, 94607, 946...                 3439
# 15  [94530, 94563, 94602, 94607, 94608, 94609, 946...                 3430
# 30  [94130, 94530, 94602, 94607, 94608, 94609, 946...                 3410
# 2   [94501, 94502, 94563, 94601, 94602, 94603, 946...                 3389
# 25  [94501, 94502, 94601, 94602, 94603, 94606, 946...                 3049
# 0   [94501, 94502, 94601, 94602, 94606, 94607, 946...                 3021
# 49  [94130, 94501, 94502, 94601, 94602, 94606, 946...                 2839
# 18  [94530, 94608, 94609, 94618, 94702, 94703, 947...                 2657
# 21  [94501, 94502, 94516, 94577, 94601, 94602, 946...                 2480
# 17  [94530, 94564, 94702, 94703, 94704, 94705, 947...                 2241
# 33  [94516, 94549, 94556, 94563, 94575, 94609, 946...                 1868
# 38  [94530, 94564, 94702, 94706, 94707, 94708, 947...                 1761
# 11  [94501, 94502, 94577, 94578, 94579, 94601, 946...                 1719
# 3   [94005, 94014, 94015, 94102, 94103, 94104, 941...                 1522
# 22  [94005, 94014, 94015, 94102, 94103, 94104, 941...                 1491
# 10  [94102, 94103, 94104, 94105, 94107, 94108, 941...                 1436
# 37  [94102, 94103, 94104, 94105, 94107, 94108, 941...                 1436
# 1   [94102, 94103, 94104, 94105, 94107, 94108, 941...                 1436
# 29  [94102, 94103, 94104, 94105, 94107, 94108, 941...                 1400
# 19  [94102, 94103, 94104, 94105, 94107, 94108, 941...                 1296
# 6   [94005, 94014, 94015, 94080, 94102, 94103, 941...                 1215
# 41  [94502, 94541, 94546, 94577, 94578, 94579, 945...                 1028
# 32  [94501, 94502, 94577, 94578, 94579, 94580, 946...                  963
# 24  [94516, 94523, 94549, 94556, 94563, 94575, 945...                  917
# 14  [94005, 94014, 94015, 94080, 94103, 94107, 941...                  914
# 46  [94507, 94518, 94523, 94549, 94556, 94575, 945...                  661
# 36  [94518, 94519, 94520, 94523, 94549, 94553, 945...                  546
# 12  [94005, 94014, 94015, 94066, 94080, 94110, 941...                  530
# 7   [94541, 94542, 94544, 94546, 94577, 94578, 945...                  474
# 44  [94005, 94014, 94015, 94030, 94044, 94066, 940...                  363
# 9   [94541, 94542, 94544, 94546, 94552, 94577, 945...                  359
# 23  [94541, 94542, 94544, 94545, 94546, 94552, 945...                  322
# 13         [94518, 94519, 94520, 94521, 94523, 94597]                  213
# 43  [94536, 94541, 94542, 94544, 94545, 94578, 945...                  155
# 31                [94518, 94519, 94520, 94521, 94523]                  139
# 40  [94005, 94010, 94014, 94015, 94030, 94044, 940...                  123
# 42  [94005, 94010, 94015, 94030, 94044, 94066, 940...                   86
# 27  [94010, 94030, 94066, 94080, 94128, 94401, 944...                   60
# 34                       [94518, 94519, 94521, 94565]                   45
# 45         [94536, 94542, 94544, 94555, 94560, 94587]                   43
# 48         [94552, 94566, 94568, 94582, 94583, 94588]                   27
# 16                [94566, 94568, 94582, 94583, 94588]                   26
# 20                [94536, 94538, 94539, 94560, 94587]                   17
# 47  [94536, 94538, 94539, 94560, 94586, 95002, 95035]                    8
# 35                              [94509, 94521, 94565]                    7
# 4                               [94509, 94531, 94561]                    0
# 28  [95035, 95050, 95053, 95054, 95110, 95112, 951...                    0
# 8   [95050, 95053, 95054, 95110, 95112, 95113, 951...                    0

# %% [markdown]
# # Create population/current customer table based on 2 mile radius from stations.

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select station
from stations
order by station

"""

df2 = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
df2
# Out:
#                  station
# 0            12th Street
# 1    16th Street Mission
# 2            19th Street
# 3    24th Street Mission
# 4                Antioch
# 5                  Ashby
# 6            Balboa Park
# 7               Bay Fair
# 8              Berryessa
# 9          Castro Valley
# 10          Civic Center
# 11              Coliseum
# 12                 Colma
# 13               Concord
# 14             Daly City
# 15     Downtown Berkeley
# 16                Dublin
# 17  El Cerrito del Norte
# 18      El Cerrito Plaza
# 19           Embarcadero
# 20               Fremont
# 21             Fruitvale
# 22             Glen Park
# 23               Hayward
# 24             Lafayette
# 25          Lake Merritt
# 26             MacArthur
# 27              Millbrae
# 28              Milpitas
# 29     Montgomery Street
# 30        North Berkeley
# 31         North Concord
# 32                   OAK
# 33                Orinda
# 34             Pittsburg
# 35      Pittsburg Center
# 36         Pleasant Hill
# 37         Powell Street
# 38              Richmond
# 39             Rockridge
# 40             San Bruno
# 41           San Leandro
# 42                   SFO
# 43         South Hayward
# 44   South San Francisco
# 45            Union City
# 46          Walnut Creek
# 47          Warm Springs
# 48           West Dublin
# 49          West Oakland

# %%
pop_2 = []

for station in df2["station"]:
    pop_2.append(my_station_get_zips(station, 2))
    
df2["pop_2"] = pop_2
df2
# Out:
#                  station     pop_2
# 0            12th Street  175958.0
# 1    16th Street Mission  339093.0
# 2            19th Street  165215.0
# 3    24th Street Mission  315201.0
# 4                Antioch   66933.0
# 5                  Ashby  173897.0
# 6            Balboa Park  253123.0
# 7               Bay Fair   93041.0
# 8              Berryessa  197640.0
# 9          Castro Valley  110328.0
# 10          Civic Center  347795.0
# 11              Coliseum  123040.0
# 12                 Colma  114402.0
# 13               Concord   87117.0
# 14             Daly City  231056.0
# 15     Downtown Berkeley  153753.0
# 16                Dublin   54420.0
# 17  El Cerrito del Norte   81472.0
# 18      El Cerrito Plaza   70450.0
# 19           Embarcadero  210921.0
# 20               Fremont   73855.0
# 21             Fruitvale   90602.0
# 22             Glen Park  287877.0
# 23               Hayward   66056.0
# 24             Lafayette   29639.0
# 25          Lake Merritt  175958.0
# 26             MacArthur  143953.0
# 27              Millbrae   22845.0
# 28              Milpitas   31170.0
# 29     Montgomery Street  268802.0
# 30        North Berkeley  134802.0
# 31         North Concord   58689.0
# 32                   OAK   84499.0
# 33                Orinda   19341.0
# 34             Pittsburg       0.0
# 35      Pittsburg Center   96081.0
# 36         Pleasant Hill   86258.0
# 37         Powell Street  303556.0
# 38              Richmond   85676.0
# 39             Rockridge  151725.0
# 40             San Bruno  110856.0
# 41           San Leandro  123740.0
# 42                   SFO   22845.0
# 43         South Hayward   93452.0
# 44   South San Francisco  186691.0
# 45            Union City  148456.0
# 46          Walnut Creek   43556.0
# 47          Warm Springs  120913.0
# 48           West Dublin   54420.0
# 49          West Oakland   42316.0

# %% [markdown]
# ### The pitsburg bart station has the same zip code as pittsburg center. It only doen't come up because the zip code area is so big it lies outside the box formed around the pitsburg bart station.

# %% [markdown]
# ### Filled in that value.

# %%
df2.at[34,"pop_2"] = 96081

# %%
zips_2 = []

for station in df2["station"]:
    zips_2.append(my_station_get_zip_list(station, 2))
    
df2["zips_2"] = zips_2
df2
# Out:
#                  station     pop_2  \
# 0            12th Street  175958.0
# 1    16th Street Mission  339093.0
# 2            19th Street  165215.0
# 3    24th Street Mission  315201.0
# 4                Antioch   66933.0
# 5                  Ashby  173897.0
# 6            Balboa Park  253123.0
# 7               Bay Fair   93041.0
# 8              Berryessa  197640.0
# 9          Castro Valley  110328.0
# 10          Civic Center  347795.0
# 11              Coliseum  123040.0
# 12                 Colma  114402.0
# 13               Concord   87117.0
# 14             Daly City  231056.0
# 15     Downtown Berkeley  153753.0
# 16                Dublin   54420.0
# 17  El Cerrito del Norte   81472.0
# 18      El Cerrito Plaza   70450.0
# 19           Embarcadero  210921.0
# 20               Fremont   73855.0
# 21             Fruitvale   90602.0
# 22             Glen Park  287877.0
# 23               Hayward   66056.0
# 24             Lafayette   29639.0
# 25          Lake Merritt  175958.0
# 26             MacArthur  143953.0
# 27              Millbrae   22845.0
# 28              Milpitas   31170.0
# 29     Montgomery Street  268802.0
# 30        North Berkeley  134802.0
# 31         North Concord   58689.0
# 32                   OAK   84499.0
# 33                Orinda   19341.0
# 34             Pittsburg   96081.0
# 35      Pittsburg Center   96081.0
# 36         Pleasant Hill   86258.0
# 37         Powell Street  303556.0
# 38              Richmond   85676.0
# 39             Rockridge  151725.0
# 40             San Bruno  110856.0
# 41           San Leandro  123740.0
# 42                   SFO   22845.0
# 43         South Hayward   93452.0
# 44   South San Francisco  186691.0
# 45            Union City  148456.0
# 46          Walnut Creek   43556.0
# 47          Warm Springs  120913.0
# 48           West Dublin   54420.0
# 49          West Oakland   42316.0
#
#                                                zips_2
# 0                 [94501, 94606, 94607, 94610, 94612]
# 1   [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 2          [94606, 94607, 94608, 94609, 94610, 94612]
# 3   [94102, 94103, 94107, 94110, 94114, 94117, 941...
# 4                                             [94509]
# 5   [94608, 94609, 94618, 94702, 94703, 94704, 947...
# 6                 [94110, 94112, 94127, 94131, 94134]
# 7                               [94578, 94579, 94580]
# 8                 [95110, 95112, 95116, 95131, 95133]
# 9                                      [94541, 94546]
# 10  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 11                       [94601, 94603, 94613, 94621]
# 12                                     [94014, 94015]
# 13                              [94518, 94519, 94520]
# 14                       [94014, 94015, 94112, 94132]
# 15  [94618, 94702, 94703, 94704, 94705, 94706, 947...
# 16                                            [94568]
# 17                              [94530, 94804, 94805]
# 18                       [94530, 94706, 94707, 94709]
# 19  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 20                                            [94536]
# 21                                     [94601, 94606]
# 22         [94110, 94112, 94114, 94127, 94131, 94134]
# 23                                            [94541]
# 24                                            [94549]
# 25                [94501, 94606, 94607, 94610, 94612]
# 26         [94607, 94608, 94609, 94610, 94612, 94618]
# 27                                     [94030, 94128]
# 28                                            [95131]
# 29  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 30  [94702, 94703, 94704, 94706, 94707, 94708, 947...
# 31                                     [94519, 94520]
# 32                              [94502, 94603, 94621]
# 33                                            [94563]
# 34                                                 []
# 35                                            [94565]
# 36                              [94518, 94523, 94597]
# 37  [94102, 94103, 94104, 94105, 94107, 94108, 941...
# 38                              [94801, 94804, 94805]
# 39  [94608, 94609, 94618, 94702, 94703, 94704, 94705]
# 40                              [94066, 94080, 94128]
# 41                              [94577, 94578, 94603]
# 42                                     [94030, 94128]
# 43                                     [94542, 94544]
# 44                       [94005, 94014, 94015, 94080]
# 45                                     [94536, 94587]
# 46                                     [94596, 94597]
# 47                                     [94538, 94539]
# 48                                            [94568]
# 49                                     [94607, 94612]

# %%
df2.at[34,"zips_2"] = [94565]

# %%
df2["current_customers_2"] = df2['zips_2'].apply(get_customers)
df2 = df2.sort_values(by=["current_customers_2"],axis=0,ascending=False)
df2
# Out:
#                  station     pop_2  \
# 5                  Ashby  173897.0
# 15     Downtown Berkeley  153753.0
# 39             Rockridge  151725.0
# 2            19th Street  165215.0
# 30        North Berkeley  134802.0
# 26             MacArthur  143953.0
# 0            12th Street  175958.0
# 25          Lake Merritt  175958.0
# 10          Civic Center  347795.0
# 37         Powell Street  303556.0
# 1    16th Street Mission  339093.0
# 29     Montgomery Street  268802.0
# 18      El Cerrito Plaza   70450.0
# 3    24th Street Mission  315201.0
# 19           Embarcadero  210921.0
# 17  El Cerrito del Norte   81472.0
# 38              Richmond   85676.0
# 21             Fruitvale   90602.0
# 49          West Oakland   42316.0
# 22             Glen Park  287877.0
# 11              Coliseum  123040.0
# 6            Balboa Park  253123.0
# 32                   OAK   84499.0
# 41           San Leandro  123740.0
# 33                Orinda   19341.0
# 7               Bay Fair   93041.0
# 36         Pleasant Hill   86258.0
# 24             Lafayette   29639.0
# 46          Walnut Creek   43556.0
# 14             Daly City  231056.0
# 44   South San Francisco  186691.0
# 13               Concord   87117.0
# 12                 Colma  114402.0
# 9          Castro Valley  110328.0
# 31         North Concord   58689.0
# 40             San Bruno  110856.0
# 43         South Hayward   93452.0
# 45            Union City  148456.0
# 27              Millbrae   22845.0
# 42                   SFO   22845.0
# 48           West Dublin   54420.0
# 23               Hayward   66056.0
# 16                Dublin   54420.0
# 20               Fremont   73855.0
# 34             Pittsburg   96081.0
# 35      Pittsburg Center   96081.0
# 4                Antioch   66933.0
# 47          Warm Springs  120913.0
# 28              Milpitas   31170.0
# 8              Berryessa  197640.0
#
#                                                zips_2  current_customers_2
# 5   [94608, 94609, 94618, 94702, 94703, 94704, 947...                 1384
# 15  [94618, 94702, 94703, 94704, 94705, 94706, 947...                 1293
# 39  [94608, 94609, 94618, 94702, 94703, 94704, 94705]                 1162
# 2          [94606, 94607, 94608, 94609, 94610, 94612]                 1124
# 30  [94702, 94703, 94704, 94706, 94707, 94708, 947...                 1118
# 26         [94607, 94608, 94609, 94610, 94612, 94618]                 1081
# 0                 [94501, 94606, 94607, 94610, 94612]                  915
# 25                [94501, 94606, 94607, 94610, 94612]                  915
# 10  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  811
# 37  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  759
# 1   [94102, 94103, 94104, 94105, 94107, 94108, 941...                  704
# 29  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  701
# 18                       [94530, 94706, 94707, 94709]                  669
# 3   [94102, 94103, 94107, 94110, 94114, 94117, 941...                  603
# 19  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  587
# 17                              [94530, 94804, 94805]                  582
# 38                              [94801, 94804, 94805]                  382
# 21                                     [94601, 94606]                  379
# 49                                     [94607, 94612]                  364
# 22         [94110, 94112, 94114, 94127, 94131, 94134]                  336
# 11                       [94601, 94603, 94613, 94621]                  305
# 6                 [94110, 94112, 94127, 94131, 94134]                  278
# 32                              [94502, 94603, 94621]                  244
# 41                              [94577, 94578, 94603]                  193
# 33                                            [94563]                  193
# 7                               [94578, 94579, 94580]                  173
# 36                              [94518, 94523, 94597]                  170
# 24                                            [94549]                  129
# 46                                     [94596, 94597]                  127
# 14                       [94014, 94015, 94112, 94132]                  122
# 44                       [94005, 94014, 94015, 94080]                   95
# 13                              [94518, 94519, 94520]                   73
# 12                                     [94014, 94015]                   45
# 9                                      [94541, 94546]                   42
# 31                                     [94519, 94520]                   37
# 40                              [94066, 94080, 94128]                   19
# 43                                     [94542, 94544]                   17
# 45                                     [94536, 94587]                   17
# 27                                     [94030, 94128]                   11
# 42                                     [94030, 94128]                   11
# 48                                            [94568]                   10
# 23                                            [94541]                   10
# 16                                            [94568]                   10
# 20                                            [94536]                    8
# 34                                            [94565]                    1
# 35                                            [94565]                    1
# 4                                             [94509]                    0
# 47                                     [94538, 94539]                    0
# 28                                            [95131]                    0
# 8                 [95110, 95112, 95116, 95131, 95133]                    0

# %%
def dist_from_ashby(station):
    
    arrive = "arrive " + str(station)
    
    return my_neo4j_shortest_path("depart Ashby", arrive)


df2["travel_time_from_ashby"] = df2["station"].apply(dist_from_ashby)
df2
# Out:
#                  station     pop_2  \
# 5                  Ashby  173897.0
# 15     Downtown Berkeley  153753.0
# 39             Rockridge  151725.0
# 2            19th Street  165215.0
# 30        North Berkeley  134802.0
# 26             MacArthur  143953.0
# 0            12th Street  175958.0
# 25          Lake Merritt  175958.0
# 10          Civic Center  347795.0
# 37         Powell Street  303556.0
# 1    16th Street Mission  339093.0
# 29     Montgomery Street  268802.0
# 18      El Cerrito Plaza   70450.0
# 3    24th Street Mission  315201.0
# 19           Embarcadero  210921.0
# 17  El Cerrito del Norte   81472.0
# 38              Richmond   85676.0
# 21             Fruitvale   90602.0
# 49          West Oakland   42316.0
# 22             Glen Park  287877.0
# 11              Coliseum  123040.0
# 6            Balboa Park  253123.0
# 32                   OAK   84499.0
# 41           San Leandro  123740.0
# 33                Orinda   19341.0
# 7               Bay Fair   93041.0
# 36         Pleasant Hill   86258.0
# 24             Lafayette   29639.0
# 46          Walnut Creek   43556.0
# 14             Daly City  231056.0
# 44   South San Francisco  186691.0
# 13               Concord   87117.0
# 12                 Colma  114402.0
# 9          Castro Valley  110328.0
# 31         North Concord   58689.0
# 40             San Bruno  110856.0
# 43         South Hayward   93452.0
# 45            Union City  148456.0
# 27              Millbrae   22845.0
# 42                   SFO   22845.0
# 48           West Dublin   54420.0
# 23               Hayward   66056.0
# 16                Dublin   54420.0
# 20               Fremont   73855.0
# 34             Pittsburg   96081.0
# 35      Pittsburg Center   96081.0
# 4                Antioch   66933.0
# 47          Warm Springs  120913.0
# 28              Milpitas   31170.0
# 8              Berryessa  197640.0
#
#                                                zips_2  current_customers_2  \
# 5   [94608, 94609, 94618, 94702, 94703, 94704, 947...                 1384
# 15  [94618, 94702, 94703, 94704, 94705, 94706, 947...                 1293
# 39  [94608, 94609, 94618, 94702, 94703, 94704, 94705]                 1162
# 2          [94606, 94607, 94608, 94609, 94610, 94612]                 1124
# 30  [94702, 94703, 94704, 94706, 94707, 94708, 947...                 1118
# 26         [94607, 94608, 94609, 94610, 94612, 94618]                 1081
# 0                 [94501, 94606, 94607, 94610, 94612]                  915
# 25                [94501, 94606, 94607, 94610, 94612]                  915
# 10  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  811
# 37  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  759
# 1   [94102, 94103, 94104, 94105, 94107, 94108, 941...                  704
# 29  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  701
# 18                       [94530, 94706, 94707, 94709]                  669
# 3   [94102, 94103, 94107, 94110, 94114, 94117, 941...                  603
# 19  [94102, 94103, 94104, 94105, 94107, 94108, 941...                  587
# 17                              [94530, 94804, 94805]                  582
# 38                              [94801, 94804, 94805]                  382
# 21                                     [94601, 94606]                  379
# 49                                     [94607, 94612]                  364
# 22         [94110, 94112, 94114, 94127, 94131, 94134]                  336
# 11                       [94601, 94603, 94613, 94621]                  305
# 6                 [94110, 94112, 94127, 94131, 94134]                  278
# 32                              [94502, 94603, 94621]                  244
# 41                              [94577, 94578, 94603]                  193
# 33                                            [94563]                  193
# 7                               [94578, 94579, 94580]                  173
# 36                              [94518, 94523, 94597]                  170
# 24                                            [94549]                  129
# 46                                     [94596, 94597]                  127
# 14                       [94014, 94015, 94112, 94132]                  122
# 44                       [94005, 94014, 94015, 94080]                   95
# 13                              [94518, 94519, 94520]                   73
# 12                                     [94014, 94015]                   45
# 9                                      [94541, 94546]                   42
# 31                                     [94519, 94520]                   37
# 40                              [94066, 94080, 94128]                   19
# 43                                     [94542, 94544]                   17
# 45                                     [94536, 94587]                   17
# 27                                     [94030, 94128]                   11
# 42                                     [94030, 94128]                   11
# 48                                            [94568]                   10
# 23                                            [94541]                   10
# 16                                            [94568]                   10
# 20                                            [94536]                    8
# 34                                            [94565]                    1
# 35                                            [94565]                    1
# 4                                             [94509]                    0
# 47                                     [94538, 94539]                    0
# 28                                            [95131]                    0
# 8                 [95110, 95112, 95116, 95131, 95133]                    0
#
#     travel_time_from_ashby
# 5                        0
# 15                     180
# 39                     539
# 2                      420
# 30                     300
# 26                     240
# 0                      540
# 25                     720
# 10                    1500
# 37                    1440
# 1                     1680
# 29                    1320
# 18                     480
# 3                     1800
# 19                    1260
# 17                     660
# 38                     960
# 21                    1020
# 49                     840
# 22                    1980
# 11                    1260
# 6                     2100
# 32                    1794
# 41                    1500
# 33                     839
# 7                     1740
# 36                    1559
# 24                    1139
# 46                    1439
# 14                    2340
# 44                    2760
# 13                    1919
# 12                    2580
# 9                     2034
# 31                    2099
# 40                    3000
# 43                    2220
# 45                    2520
# 27                    3420
# 42                    3288
# 48                    2634
# 23                    1980
# 16                    2814
# 20                    2820
# 34                    2459
# 35                    3059
# 4                     3479
# 47                    3180
# 28                    3720
# 8                     4020
